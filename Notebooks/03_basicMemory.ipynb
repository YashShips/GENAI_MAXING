# %%
from dotenv import load_dotenv
load_dotenv()

from langchain_google_genai import ChatGoogleGenerativeAI
llm = ChatGoogleGenerativeAI( model = "gemini-3.5-flash-lite" )

# %%
history = []
while True:
    query = input("What's up bro? ")
    if query.lower() in ["exit", "bye", "nikal"]:
        print("Aight bro")
        break

    history.append({"role" : "user", "content" : query})
    print("User: ", query)
    res = llm.invoke(history)
    history.append({"role" : "ai", "content" : res.content})
    print("AI: ", res.content)
# Out:
# User:  hey bro im yash
# AI:  Hey Yash! Nice to meet you. How's it going, bro? What are we working on today?
# User:  i am planning on buying a watch, how is the casio ae1200
# AI:  Oh man, the Casio AE-1200? You are looking at an absolute legend, bro.
#
# Often called the **"Casio Royale"** (because it kind of looks like the Seiko watch James Bond wore in *Octopussy*), it is easily one of the best value-for-money watches on the entire planet.
#
# Here is the real breakdown of why it’s so hyped:
#
# ### The Good:
# * **The Look:** It’s got that cool, retro-futuristic cyberpunk/spy vibe. It looks way more expensive than it actually is (which is usually around $30–$40).
# * **Insane Features:** World time (you can see multiple time zones at once), a 10-year battery, 100m water resistance, alarms, stopwatch, and a really good amber backlight.
# * **The Map:** That little world map in the corner that shows what time zone you're looking at? Pure nerd joy.
# * **Modding Community:** If you're into DIY stuff, people mod these things like crazy—putting them in metal cases, hydro-modding them (filling the case with oil for better viewing angles), or swapping straps.
#
# ### The Not-So-Good:
# * **Resin Case:** The body is actually painted plastic, not stainless steel (even if you get the silver-colored one). It can scratch or wear down over time if you beat it up, though at that price, it's not the end of the world.
# * **Size:** It has a wide footprint, but because it's so thin and lightweight, it wears super comfortably on almost any wrist.
#
# **Verdict:** If you like the digital retro look, **do it.** It's a staple in almost every watch collector's box, whether they own Rolexes or just starting out.
#
# Are you looking at the classic silver resin one, the black one, or thinking about doing any mods to it?
# User:  is it a good watch for professional settings too? if i buy it in the steel version?
# AI:  That is the million-dollar question, Yash!
#
# The short answer is: **It depends on how strict your workplace is, but generally speaking... yes, it can totally work, especially the "silver" (steel-look) version.**
#
# Here is the honest breakdown of pulling off the Casio Royale in a professional setting:
#
# ### 1. The "Silicon Valley / Tech / Casual" Office: **10/10**
# If your workplace is pretty relaxed—think tech, creative agencies, startups, or anywhere business-casual is the norm (button-down, chinos, maybe a sweater)—the AE-1200 actually looks *cool*. It gives off a smart, retro-geek, "I know my stuff" vibe. People who are into watches will spot it and nod in respect.
#
# ### 2. The "Strict Corporate / Banking / Law" Office: **5/10**
# If you are wearing a full, tailored suit, a tie, and working in traditional finance, corporate law, or high-end consulting, digital watches generally raise an eyebrow. Even the silver AE-1200 is still fundamentally a resin (plastic) digital watch with a lot going on on the dial. A purist might say it clashes with formal business wear.
#
# ### How to make it work in a professional setting:
# If you want to wear it to work and keep it looking sharp, here is the secret: **Upgrade the strap.**
#
# The stock resin strap that comes with it makes it look a bit too casual/sporty. But if you put the silver version on:
# * A **black or dark brown leather strap**, or
# * A **fine Milanese mesh metal bracelet**
#
# ...it instantly elevates the watch. It tones down the "neredy/spy" look and makes it look surprisingly sleek and dressy under a shirt cuff.
#
# ### Final Verdict:
# If you work in a standard casual/business-casual office, buy it in the silver version, rock it with confidence, and you'll be fine.
#
# If you are wearing a three-piece suit every day, it might be a *little* too casual, and you might want to look at something like a **Casio MTP-VD01** or a **Casio Duro** (on a bracelet) for that clean, analog look.
#
# What kind of work setting are you planning to wear it in, bro?
# User:  office bro
# AI:  Gotcha, bro. Standard office vibes!
#
# If it's just a regular office where people wear things like button-downs, polos, chinos, or sweaters, the silver AE-1200 will fit right in. Honestly, nobody is going to bat an eye—in fact, like I said, watch nerds will probably give you a nod, and most people will just think it looks cool and retro.
#
# Just do yourself one favor: if you want it to look sharp enough for the office right out of the box, **go for the silver version with the metal bracelet** (Model: AE1200WHD-1AV). The metal bracelet makes it look a lot cleaner with work clothes than the black resin version does.
#
# Rock it with a nice shirt, and you're golden, Yash.
#
# Are you ready to pull the trigger and grab one, or are you still browsing around?
# User:  thanks bro
# AI:  Anytime, bro! Enjoy the Casio Royale—it's an absolute classic and you're gonna love rocking it at the office.
#
# If you ever need help picking out another watch (because trust me, watch collecting becomes an addiction real quick 😂) or anything else, just hit me up. Have a good one, Yash!
# Aight bro
