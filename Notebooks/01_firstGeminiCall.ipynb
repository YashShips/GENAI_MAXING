# %% [markdown]
# Confiming if our API Key has been written into our .env file

# %%
from dotenv import load_dotenv
import os 
load_dotenv()
res = os.getenv("GOOGLE_API_KEY")
print(res[:10])
# Out:
# AQ.Ab8RN6K

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm = ChatGoogleGenerativeAI(
    model = "gemini-3.5-flash-lite"
)
resp = llm.invoke("Who is the president of India?")
print(resp.content)
# Out:
# The current President of India is **Droupadi Murmu**. She assumed office on July 25, 2022, as the 15th President of India.
